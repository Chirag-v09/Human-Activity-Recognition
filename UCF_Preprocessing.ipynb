# %% [markdown]
# # Preprocessing

# %%
# Importing Essential Libraries
import os
import cv2
import time
import glob
import random
from tqdm import tqdm

# %%
# Required Parameters
dataset = "UCF-101/"                # Dataset Path
dataset2 = "dataset/"               # Dataset2 Path
train_path = "training_set/"        # Training Path
test_path = "testing_set/"          # Testing Path
no_of_frames = 1650                 # Number of Frames
ch = 4                              # Model Selection Choice
epochs = 20                         # Number of epochs
batch_size = 32                     # Batch Size
n_classes = 101                     # Number of Classes
patience = 2                        # Patience for EarlyStopping
stime = int(time.time())            # Defining Starting Time
categories = os.listdir(dataset)    # Name of each Class/Category

# %%
# Creating training_set directory
try:
    os.mkdir(train_path)
    print("Folder {} created...".format(train_path))
except:
    print("A folder {} already exists...".format(train_path))
# Out:
# A folder training_set/ already exists...

# %%
# Creating training_set directory
try:
    os.mkdir(train_path)
    print("Folder {} created...".format(train_path))
except:
    print("A folder {} already exists...".format(train_path))
# Out:
# A folder training_set/ already exists...

# %%
# Creating testing_set directory
try:
    os.mkdir(test_path)
    print("Folder {} created...".format(test_path))
except:
    print("A folder {} already exists...".format(test_path))
# Out:
# A folder testing_set/ already exists...

# %%
# Creating same directories for training_set/ that are already present in the dataset directory
for category in categories:
    try:
        os.mkdir(train_path + category)
        print("Folder {} created...".format(category))
    except:
        print("A folder already exists, named {}...".format(category, train_path))
# Out:
# A folder already exists, named ApplyEyeMakeup...
# A folder already exists, named ApplyLipstick...
# A folder already exists, named Archery...
# A folder already exists, named BabyCrawling...
# A folder already exists, named BalanceBeam...
# A folder already exists, named BandMarching...
# A folder already exists, named BaseballPitch...
# A folder already exists, named Basketball...
# A folder already exists, named BasketballDunk...
# A folder already exists, named BenchPress...
# A folder already exists, named Biking...
# A folder already exists, named Billiards...
# A folder already exists, named BlowDryHair...
# A folder already exists, named BlowingCandles...
# A folder already exists, named BodyWeightSquats...
# A folder already exists, named Bowling...
# A folder already exists, named BoxingPunchingBag...
# A folder already exists, named BoxingSpeedBag...
# A folder already exists, named BreastStroke...
# A folder already exists, named BrushingTeeth...
# A folder already exists, named CleanAndJerk...
# A folder already exists, named CliffDiving...
# A folder already exists, named CricketBowling...
# A folder already exists, named CricketShot...
# A folder already exists, named CuttingInKitchen...
# A folder already exists, named Diving...
# A folder already exists, named Drumming...
# A folder already exists, named Fencing...
# A folder already exists, named FieldHockeyPenalty...
# A folder already exists, named FloorGymnastics...
# A folder already exists, named FrisbeeCatch...
# A folder already exists, named FrontCrawl...
# A folder already exists, named GolfSwing...
# A folder already exists, named Haircut...
# A folder already exists, named Hammering...
# A folder already exists, named HammerThrow...
# A folder already exists, named HandstandPushups...
# A folder already exists, named HandstandWalking...
# A folder already exists, named HeadMassage...
# A folder already exists, named HighJump...
# A folder already exists, named HorseRace...
# A folder already exists, named HorseRiding...
# A folder already exists, named HulaHoop...
# A folder already exists, named IceDancing...
# A folder already exists, named JavelinThrow...
# A folder already exists, named JugglingBalls...
# A folder already exists, named JumpingJack...
# A folder already exists, named JumpRope...
# A folder already exists, named Kayaking...
# A folder already exists, named Knitting...
# A folder already exists, named LongJump...
# A folder already exists, named Lunges...
# A folder already exists, named MilitaryParade...
# A folder already exists, named Mixing...
# A folder already exists, named MoppingFloor...
# A folder already exists, named Nunchucks...
# A folder already exists, named ParallelBars...
# A folder already exists, named PizzaTossing...
# A folder already exists, named PlayingCello...
# A folder already exists, named PlayingDaf...
# A folder already exists, named PlayingDhol...
# A folder already exists, named PlayingFlute...
# A folder already exists, named PlayingGuitar...
# A folder already exists, named PlayingPiano...
# A folder already exists, named PlayingSitar...
# A folder already exists, named PlayingTabla...
# A folder already exists, named PlayingViolin...
# A folder already exists, named PoleVault...
# A folder already exists, named PommelHorse...
# A folder already exists, named PullUps...
# A folder already exists, named Punch...
# A folder already exists, named PushUps...
# A folder already exists, named Rafting...
# A folder already exists, named RockClimbingIndoor...
# A folder already exists, named RopeClimbing...
# A folder already exists, named Rowing...
# A folder already exists, named SalsaSpin...
# A folder already exists, named ShavingBeard...
# A folder already exists, named Shotput...
# A folder already exists, named SkateBoarding...
# A folder already exists, named Skiing...
# A folder already exists, named Skijet...
# A folder already exists, named SkyDiving...
# A folder already exists, named SoccerJuggling...
# A folder already exists, named SoccerPenalty...
# A folder already exists, named StillRings...
# A folder already exists, named SumoWrestling...
# A folder already exists, named Surfing...
# A folder already exists, named Swing...
# A folder already exists, named TableTennisShot...
# A folder already exists, named TaiChi...
# A folder already exists, named TennisSwing...
# A folder already exists, named ThrowDiscus...
# A folder already exists, named TrampolineJumping...
# A folder already exists, named Typing...
# A folder already exists, named UnevenBars...
# A folder already exists, named VolleyballSpiking...
# A folder already exists, named WalkingWithDog...
# A folder already exists, named WallPushups...
# A folder already exists, named WritingOnBoard...
# A folder already exists, named YoYo...

# %%
# Creating same directories for testing_set/ that are already present in the dataset directory
for category in categories:
    try:
        os.mkdir(test_path  + category)
        print("Folder {} created...".format(category))
    except:
        print("A folder already exists, named {}...".format(category, test_path))
# Out:
# A folder already exists, named ApplyEyeMakeup...
# A folder already exists, named ApplyLipstick...
# A folder already exists, named Archery...
# A folder already exists, named BabyCrawling...
# A folder already exists, named BalanceBeam...
# A folder already exists, named BandMarching...
# A folder already exists, named BaseballPitch...
# A folder already exists, named Basketball...
# A folder already exists, named BasketballDunk...
# A folder already exists, named BenchPress...
# A folder already exists, named Biking...
# A folder already exists, named Billiards...
# A folder already exists, named BlowDryHair...
# A folder already exists, named BlowingCandles...
# A folder already exists, named BodyWeightSquats...
# A folder already exists, named Bowling...
# A folder already exists, named BoxingPunchingBag...
# A folder already exists, named BoxingSpeedBag...
# A folder already exists, named BreastStroke...
# A folder already exists, named BrushingTeeth...
# A folder already exists, named CleanAndJerk...
# A folder already exists, named CliffDiving...
# A folder already exists, named CricketBowling...
# A folder already exists, named CricketShot...
# A folder already exists, named CuttingInKitchen...
# A folder already exists, named Diving...
# A folder already exists, named Drumming...
# A folder already exists, named Fencing...
# A folder already exists, named FieldHockeyPenalty...
# A folder already exists, named FloorGymnastics...
# A folder already exists, named FrisbeeCatch...
# A folder already exists, named FrontCrawl...
# A folder already exists, named GolfSwing...
# A folder already exists, named Haircut...
# A folder already exists, named Hammering...
# A folder already exists, named HammerThrow...
# A folder already exists, named HandstandPushups...
# A folder already exists, named HandstandWalking...
# A folder already exists, named HeadMassage...
# A folder already exists, named HighJump...
# A folder already exists, named HorseRace...
# A folder already exists, named HorseRiding...
# A folder already exists, named HulaHoop...
# A folder already exists, named IceDancing...
# A folder already exists, named JavelinThrow...
# A folder already exists, named JugglingBalls...
# A folder already exists, named JumpingJack...
# A folder already exists, named JumpRope...
# A folder already exists, named Kayaking...
# A folder already exists, named Knitting...
# A folder already exists, named LongJump...
# A folder already exists, named Lunges...
# A folder already exists, named MilitaryParade...
# A folder already exists, named Mixing...
# A folder already exists, named MoppingFloor...
# A folder already exists, named Nunchucks...
# A folder already exists, named ParallelBars...
# A folder already exists, named PizzaTossing...
# A folder already exists, named PlayingCello...
# A folder already exists, named PlayingDaf...
# A folder already exists, named PlayingDhol...
# A folder already exists, named PlayingFlute...
# A folder already exists, named PlayingGuitar...
# A folder already exists, named PlayingPiano...
# A folder already exists, named PlayingSitar...
# A folder already exists, named PlayingTabla...
# A folder already exists, named PlayingViolin...
# A folder already exists, named PoleVault...
# A folder already exists, named PommelHorse...
# A folder already exists, named PullUps...
# A folder already exists, named Punch...
# A folder already exists, named PushUps...
# A folder already exists, named Rafting...
# A folder already exists, named RockClimbingIndoor...
# A folder already exists, named RopeClimbing...
# A folder already exists, named Rowing...
# A folder already exists, named SalsaSpin...
# A folder already exists, named ShavingBeard...
# A folder already exists, named Shotput...
# A folder already exists, named SkateBoarding...
# A folder already exists, named Skiing...
# A folder already exists, named Skijet...
# A folder already exists, named SkyDiving...
# A folder already exists, named SoccerJuggling...
# A folder already exists, named SoccerPenalty...
# A folder already exists, named StillRings...
# A folder already exists, named SumoWrestling...
# A folder already exists, named Surfing...
# A folder already exists, named Swing...
# A folder already exists, named TableTennisShot...
# A folder already exists, named TaiChi...
# A folder already exists, named TennisSwing...
# A folder already exists, named ThrowDiscus...
# A folder already exists, named TrampolineJumping...
# A folder already exists, named Typing...
# A folder already exists, named UnevenBars...
# A folder already exists, named VolleyballSpiking...
# A folder already exists, named WalkingWithDog...
# A folder already exists, named WallPushups...
# A folder already exists, named WritingOnBoard...
# A folder already exists, named YoYo...

# %%
# Combining multiple videos into single video file
for category in tqdm(categories):
    videofiles = [dataset + category + "/" + n for n in os.listdir(dataset + category) if n[-4:]==".avi"]
    video_index = 0
    cap = cv2.VideoCapture(videofiles[0])    
    fourcc = cv2.VideoWriter_fourcc(*"XVID")
    # fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    out = cv2.VideoWriter("{}/{}/{}.avi".format(dataset2, category, category), fourcc, 25, (320, 240))
    while(cap.isOpened()):
        ret, frame = cap.read()
        if frame is None:
            video_index += 1
            if video_index >= len(videofiles):
                break
            else:
                cap = cv2.VideoCapture(videofiles[ video_index ])
                ret, frame = cap.read()
                out.write(frame)
        else:
            out.write(frame)
    cap.release()
    out.release()
    cv2.destroyAllWindows()

# %%
# # Extracting one frame per five frame from the Videos
# for category in tqdm(categories):
#     count = 0    
#     a = glob.glob(dataset + '/' + category + '/*.avi')
#     for i in range(len(a)):
#         cap = cv2.VideoCapture(a[i])
#         frameRate = cap.get(5)
#         while(cap.isOpened()):
#             frameId = cap.get(1)
#             ret, frame = cap.read()
#             if (ret != True):
#                 break
#             if (frameId % math.floor(frameRate) == 0):
#                 cv2.imwrite(train_path + '/' + category + '/{}_{}.jpg'.format(category, count), frame)
#                 count += 1
#         cap.release()

# %%
# # Extracting every frame from the Videos
# for category in tqdm(categories):
#     count = 0    
#     a = glob.glob(dataset + category + '/*.avi')
#     for i in range(len(a)):
#         cap = cv2.VideoCapture(a[i])
#         # frameRate = cap.get(5)
#         while(cap.isOpened()):
#             # frameId = cap.get(1)
#             ret, frame = cap.read()
#             if (ret != True):
#                 break
#             # if (frameId % math.floor(frameRate) == 0):
#             else:
#                 cv2.imwrite(train_path + category + '/{}_{}.jpg'.format(category, count), frame)
#                 count += 1
#         cap.release()

# %%
train_files = [file for file in glob.glob(dataset2 + "*")]

# Getting total no. of frames in each classes
total_frames = []
for category in tqdm(categories):
    cap = cv2.VideoCapture(dataset2 + category + "/" + category + ".avi")
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    total_frames.append(length)
    cap.release()
    cv2.destroyAllWindows()

# %%
# Extracting 1650 images from each category
for i in tqdm(range(len(train_files))):
    count = 0
    cap = cv2.VideoCapture(train_files[i] + "\\" + train_files[i].split("\\")[-1] + ".avi")
    while(cap.isOpened()):
        frame_id = cap.get(1)
        ret, frame = cap.read()
        if ret != True:
            print("Exiting...")
            break
        if frame_id % int(total_frames[i] / no_of_frames) == 0.0:
            if count >= 1650:
                break
            file_name = "training_set\\" + train_files[i].split("\\")[-1] + "\\frame_{}.jpg".format(count); count += 1
            cv2.imwrite(file_name, frame)
    cap.release()
    cv2.destroyAllWindows()

# %%
# for category in tqdm(categories):
#     count = 0
#     cap = cv2.VideoCapture(train_path + category + "/" + category + ".avi")
#     while(cap.isOpened()):
#         frame_id = cap.get(1)
#         ret, frame = cap.read()
#         if ret != True:
#             print("Exiting...")
#             break
#         if frame_id % int(total_frames[i] / no_of_frames) == 0.0:
#             if count >= 1650:
#                 break
#             file_name = train_path + category + "/frame_{}.jpg".format(count); count += 1
#             cv2.imwrite(file_name, frame)
#     cap.release()
#     cv2.destroyAllWindows()s

# %%
train_files = [file for file in glob.glob(train_path + "*")]

# Moving random imgaes from training_set into testing_set
for train_file in tqdm(train_files):
    sub_file = [file for file in glob.glob(train_file + "\*")]
    test_files = random.sample(sub_file, 150)
    for test_file in test_files:
        img = cv2.imread(test_file)
        os.remove(test_file)
        cv2.imwrite(test_path + test_file.split("\\")[1] + "\\" + test_file.split("\\")[-1] , img)

# %%
# Counting number of images in each folder of training set
for category in categories:
    print(len(os.listdir(train_path + category)), "in training &",
          len(os.listdir(test_path + category)), "in testing", ":", category)
# Out:
# 1500 in training & 150 in testing : ApplyEyeMakeup
# 1500 in training & 150 in testing : ApplyLipstick
# 1500 in training & 150 in testing : Archery
# 1500 in training & 150 in testing : BabyCrawling
# 1500 in training & 150 in testing : BalanceBeam
# 1500 in training & 150 in testing : BandMarching
# 1500 in training & 150 in testing : BaseballPitch
# 1500 in training & 150 in testing : Basketball
# 1500 in training & 150 in testing : BasketballDunk
# 1500 in training & 150 in testing : BenchPress
# 1500 in training & 150 in testing : Biking
# 1500 in training & 150 in testing : Billiards
# 1500 in training & 150 in testing : BlowDryHair
# 1500 in training & 150 in testing : BlowingCandles
# 1500 in training & 150 in testing : BodyWeightSquats
# 1500 in training & 150 in testing : Bowling
# 1500 in training & 150 in testing : BoxingPunchingBag
# 1500 in training & 150 in testing : BoxingSpeedBag
# 1500 in training & 150 in testing : BreastStroke
# 1500 in training & 150 in testing : BrushingTeeth
# 1500 in training & 150 in testing : CleanAndJerk
# 1500 in training & 150 in testing : CliffDiving
# 1500 in training & 150 in testing : CricketBowling
# 1500 in training & 150 in testing : CricketShot
# 1500 in training & 150 in testing : CuttingInKitchen
# 1500 in training & 150 in testing : Diving
# 1500 in training & 150 in testing : Drumming
# 1500 in training & 150 in testing : Fencing
# 1500 in training & 150 in testing : FieldHockeyPenalty
# 1500 in training & 150 in testing : FloorGymnastics
# 1500 in training & 150 in testing : FrisbeeCatch
# 1500 in training & 150 in testing : FrontCrawl
# 1500 in training & 150 in testing : GolfSwing
# 1500 in training & 150 in testing : Haircut
# 1500 in training & 150 in testing : Hammering
# 1500 in training & 150 in testing : HammerThrow
# 1500 in training & 150 in testing : HandstandPushups
# 1500 in training & 150 in testing : HandstandWalking
# 1500 in training & 150 in testing : HeadMassage
# 1500 in training & 150 in testing : HighJump
# 1500 in training & 150 in testing : HorseRace
# 1500 in training & 150 in testing : HorseRiding
# 1500 in training & 150 in testing : HulaHoop
# 1500 in training & 150 in testing : IceDancing
# 1500 in training & 150 in testing : JavelinThrow
# 1500 in training & 150 in testing : JugglingBalls
# 1500 in training & 150 in testing : JumpingJack
# 1500 in training & 150 in testing : JumpRope
# 1500 in training & 150 in testing : Kayaking
# 1500 in training & 150 in testing : Knitting
# 1500 in training & 150 in testing : LongJump
# 1500 in training & 150 in testing : Lunges
# 1500 in training & 150 in testing : MilitaryParade
# 1500 in training & 150 in testing : Mixing
# 1500 in training & 150 in testing : MoppingFloor
# 1500 in training & 150 in testing : Nunchucks
# 1500 in training & 150 in testing : ParallelBars
# 1500 in training & 150 in testing : PizzaTossing
# 1500 in training & 150 in testing : PlayingCello
# 1500 in training & 150 in testing : PlayingDaf
# 1500 in training & 150 in testing : PlayingDhol
# 1500 in training & 150 in testing : PlayingFlute
# 1500 in training & 150 in testing : PlayingGuitar
# 1500 in training & 150 in testing : PlayingPiano
# 1500 in training & 150 in testing : PlayingSitar
# 1500 in training & 150 in testing : PlayingTabla
# 1500 in training & 150 in testing : PlayingViolin
# 1500 in training & 150 in testing : PoleVault
# 1500 in training & 150 in testing : PommelHorse
# 1500 in training & 150 in testing : PullUps
# 1500 in training & 150 in testing : Punch
# 1500 in training & 150 in testing : PushUps
# 1500 in training & 150 in testing : Rafting
# 1500 in training & 150 in testing : RockClimbingIndoor
# 1500 in training & 150 in testing : RopeClimbing
# 1500 in training & 150 in testing : Rowing
# 1500 in training & 150 in testing : SalsaSpin
# 1500 in training & 150 in testing : ShavingBeard
# 1500 in training & 150 in testing : Shotput
# 1500 in training & 150 in testing : SkateBoarding
# 1500 in training & 150 in testing : Skiing
# 1500 in training & 150 in testing : Skijet
# 1500 in training & 150 in testing : SkyDiving
# 1500 in training & 150 in testing : SoccerJuggling
# 1500 in training & 150 in testing : SoccerPenalty
# 1500 in training & 150 in testing : StillRings
# 1500 in training & 150 in testing : SumoWrestling
# 1500 in training & 150 in testing : Surfing
# 1500 in training & 150 in testing : Swing
# 1500 in training & 150 in testing : TableTennisShot
# 1500 in training & 150 in testing : TaiChi
# 1500 in training & 150 in testing : TennisSwing
# 1500 in training & 150 in testing : ThrowDiscus
# 1500 in training & 150 in testing : TrampolineJumping
# 1500 in training & 150 in testing : Typing
# 1500 in training & 150 in testing : UnevenBars
# 1500 in training & 150 in testing : VolleyballSpiking
# 1500 in training & 150 in testing : WalkingWithDog
# 1500 in training & 150 in testing : WallPushups
# 1500 in training & 150 in testing : WritingOnBoard
# 1500 in training & 150 in testing : YoYo
